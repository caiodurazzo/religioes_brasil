# %% [markdown]
# ## Reprodução dados

# %% [markdown]
# Nesse notebook são reproduzidos os dados do livro devido à dificuldade de acesso a todos os dados originais do IBGE

# %% [markdown]
# O esforço de extração dos dados originais é válido e deve ser implementado posteriormente

# %%
import pandas as pd
from utils.save_csv import save_csv

# %%
data = {
    'Ano': [1872,1890,1940,1950,1960,1970,1980,1991,2000,2010,2022],
    'Católica': [100,99,95,93,92,90,87,83,74,65,57],
    'Evangélica': [0,1,3,3,4,5,7,9,15,22,27],
    'Outras': [0,0,0,3,3,4,3,3,4,5,7],
    'Sem religião': [0,0,0,1,1,1,3,5,7,8,9]
}

# %%
df = pd.DataFrame(data)

# %%
save_csv(df, 'dados_religioes_brasil.csv')
# Out:
# Base salva em data\dados_religioes_brasil.csv
